# %% [markdown]
# <a href="https://colab.research.google.com/github/Shavkatov-dev/computer_vision/blob/main/data_scarping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Uzb!")
# Out:
# Hello Uzb!

# %%
# !pip install bing-image-downloader

# %%
from bing_image_downloader import downloader

# %%
downloader.download("uzbek pilaf plov food",
                    limit=100,
                    output_dir="/content/pilaf_images",
                    adult_filter_off=True,
                    force_replace=False,
                    timeout=60
                    )
# Out:
# [%] Downloading Images to /content/pilaf_images/uzbek pilaf plov food
#
#
# [!!] Indexing page: 1
#
# [%] Indexed 100 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.advantour.com/img/uzbekistan/culture/uzbekistan-culture-dance.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #2 from https://i.pinimg.com/originals/63/a7/dd/63a7dd0f6b886e1c0e0793c6dfb8f2e5.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #3 from http://www.advantour.com/img/uzbekistan/culture/uzbek-dance8.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #4 from https://s-media-cache-ak0.pinimg.com/736x/31/52/cc/3152ccf7c7ac055787b5db5699f5f542.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #5 from https://central-asia.guide/wp-content/uploads/2021/07/men_traditional_clothes_uzbek-1536x1024.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #6 from https://voicesoncentralasia.org/wp-content/uploads/2020/12/Image_2_CADC2019EmbassyPerformancePostConcert.jpeg
# [%] File Downloaded!
#
# ...

# %%
downloader.download("caesar salad",
                    limit=100,
                    output_dir="/content/caesar_salad",
                    adult_filter_off=True,
                    force_replace=False,
                    timeout=60
                    )
# Out:
# [%] Downloading Images to /content/caesar_salad/caesar salad
#
#
# [!!] Indexing page: 1
#
# [%] Indexed 73 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://assets.thelocal.com/cdn-cgi/rs:fit:850/quality:75/plain/https://apiwp.thelocal.com/wp-content/uploads/2024/04/AFP__20221208__32ZT48H__v1__Preview__AndorraInternetMediaTaxPeople.jpg@webp
# [%] File Downloaded!
#
# [%] Downloading Image #2 from https://visitandorra.com/content/dam/visitandorra/ca/assets/images/què-fer/countrybreak/andorraworld-desantis-carolina-2024-2024--Andorra-la-Vella--Carolina-De-Santis-3V7A9390.jpg
# [%] File Downloaded!
#
# [%] Downloading Image #3 from https://storage.googleapis.com/world-travel-guide/2025/01/Climate-Of-Andorra-1024x681.jpg
# [%] File Downloaded!
#
# ...

# %%
# !rm -rf /content/drive/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os, shutil
source_dir = "/content/pilaf_images/uzbek pilaf plov food"
target_dir = "/content/drive/MyDrive/kaggle/images/pilaf_images"

os.makedirs(target_dir, exist_ok=True)
for filename in os.listdir(source_dir):
  src_file = os.path.join(source_dir, filename)
  dst_file = os.path.join(target_dir, filename)
  shutil.copy(src_file, dst_file)

# %%
downloader.download("kebab shashlik food",
                    limit=100,
                    output_dir="/content/kebab_images",
                    adult_filter_off=True,
                    force_replace=False,
                    timeout=60
                    )
# Out:
# [%] Downloading Images to /content/kebab_images/kebab shashlik food
#
#
# [!!] Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://down-tw.img.susercontent.com/file/tw-11134202-7r98u-lt3w5mp5a4w96e
# [%] File Downloaded!
#
# [%] Downloading Image #2 from https://down-tw.img.susercontent.com/file/tw-11134208-7ra0r-mbkte76qci6rd1
# [%] File Downloaded!
#
# [%] Downloading Image #3 from https://down-tw.img.susercontent.com/file/tw-11134202-7quky-lg2ojgynz4mi6e
# [%] File Downloaded!
#
# [%] Downloading Image #4 from https://down-tw.img.susercontent.com/file/tw-11134208-7r98t-lt6f3r5q71u013
# [%] File Downloaded!
#
# [%] Downloading Image #5 from https://down-tw.img.susercontent.com/file/tw-11134202-7rbk8-m6f8cuwsgxmn9a
# [%] File Downloaded!
#
# [%] Downloading Image #6 from https://down-tw.img.susercontent.com/file/tw-11134208-7qukx-lj9mn4p6jyyc4f
# [%] File Downloaded!
#
# ...

# %%
import os, shutil
source_dir = "/content/kebab_images/kebab shashlik food"
target_dir = "/content/drive/MyDrive/kaggle/images/kebab_images"

os.makedirs(target_dir, exist_ok=True)
for filename in os.listdir(source_dir):
  src_file = os.path.join(source_dir, filename)
  dst_file = os.path.join(target_dir, filename)
  shutil.copy(src_file, dst_file)
